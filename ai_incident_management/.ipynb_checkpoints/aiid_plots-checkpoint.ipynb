# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from wordcloud import WordCloud

# %%
aiid_data = pd.read_csv("aiid_data_pull_20231213.csv")
aiid_data.head(3)
len(aiid_data)
# Out:
# 605

# %%
aiid_data.dtypes
# Out:
# id                                         object
# title                                      object
# description                                object
# date                                       object
# alleged_deployer_of_ai_system              object
# alleged_developer_of_ai_system             object
# alleged_harmed_or_nearly_harmed_parties    object
# dtype: object

# %%
aiid_data['alleged_deployer_of_ai_system'].value_counts()
# Out:
# alleged_deployer_of_ai_system
# Tesla                                            38
# Facebook                                         36
# Google                                           28
# unknown                                          22
# Amazon                                           21
#                                                  ..
# Pasco Sheriff's Office                            1
# unnamed Australian telecommunications company     1
# Estée Lauder                                      1
# Naver                                             1
# The Arena Group, Sports Illustrated               1
# Name: count, Length: 351, dtype: int64

# %%
aiid_data['alleged_developer_of_ai_system'].value_counts()
# Out:
# alleged_developer_of_ai_system
# unknown                                                                  86
# Tesla                                                                    42
# Facebook                                                                 36
# OpenAI                                                                   27
# Google                                                                   27
#                                                                          ..
# Sarawak Information Systems                                               1
# Airbnb, Trooly                                                            1
# SecurOS                                                                   1
# Spanish Secretary of State for Security, Spanish Ministry of Interior     1
# Google Bard                                                               1
# Name: count, Length: 266, dtype: int64

# %%
aiid_data['alleged_harmed_or_nearly_harmed_parties'].value_counts()
# Out:
# alleged_harmed_or_nearly_harmed_parties
# Facebook users                                                           7
# Tesla drivers                                                            6
# Women, Minority Groups                                                   5
# unknown                                                                  4
# Microsoft                                                                4
#                                                                         ..
# Facebook content moderators                                              1
# Black students                                                           1
# XPeng Motors customers                                                   1
# Indian voters, Indian social media users, Indian women journalists       1
# General public, Readers of Sports Illustrated, Journalistic integrity    1
# Name: count, Length: 553, dtype: int64

# %%
# convert type of date field
aiid_data['date'] = aiid_data['date'].astype('datetime64[ns]')
aiid_data.dtypes
# Out:
# /var/folders/qy/2qlsgz6s43xbn14whr8v3sbh0000gn/T/ipykernel_20739/2921060104.py:2: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   aiid_data['date'] = aiid_data['date'].astype('datetime64[ns]')
# id                                                 object
# title                                              object
# description                                        object
# date                                       datetime64[ns]
# alleged_deployer_of_ai_system                      object
# alleged_developer_of_ai_system                     object
# alleged_harmed_or_nearly_harmed_parties            object
# dtype: object

# %%
# add day, month, and year to data
datetimes = pd.to_datetime(aiid_data['date'])

aiid_data['day'] = datetimes.dt.day
aiid_data['month'] = datetimes.dt.month
aiid_data['year'] = datetimes.dt.year

aiid_data.head(2)
# Out:
#            id                                              title  \
# 0  Incident 1  Google’s YouTube Kids App Presents Inappropria...
# 1  Incident 2  Warehouse robot ruptures can of bear spray and...
#
#                                          description       date  \
# 0  YouTube’s content filtering and recommendation... 2015-05-19
# 1  Twenty-four Amazon workers in New Jersey were ... 2018-12-05
#
#   alleged_deployer_of_ai_system alleged_developer_of_ai_system  \
# 0                       YouTube                        YouTube
# 1                        Amazon                         Amazon
#
#   alleged_harmed_or_nearly_harmed_parties  day  month  year
# 0                                Children   19      5  2015
# 1                       Warehouse Workers    5     12  2018

# %%
# top 5 years of incident count
aiid_data['year'].value_counts().head(5)
# Out:
# year
# 2023    114
# 2022     93
# 2020     82
# 2021     71
# 2017     48
# Name: count, dtype: int64

# %%
# explore 522
print(f'**Title**: {aiid_data["title"][522]}')
print(f"**Description**: {aiid_data['description'][522]}")
print(f"**Deployer**: {aiid_data['alleged_deployer_of_ai_system'][522]}")
print(f"**Developer**: {aiid_data['alleged_developer_of_ai_system'][522]}")
print(f"**Date**: {aiid_data['date'][522]}")
print(f"**Victim(s)**: {aiid_data['alleged_harmed_or_nearly_harmed_parties'][522]}")
# Out:
# **Title**: Tesla FSD Misidentified Truck Hauling Traffic Lights as Trail of Traffic Lights
# **Description**: A Tesla driver posted on Twitter his Tesla FSD's "glitch," misidentifying deactivated traffic lights being carried by a truck as a constant trail of traffic lights while traveling at high speed on a highway.
# **Deployer**: Tesla
# **Developer**: Tesla
# **Date**: 2021-06-02 00:00:00
# **Victim(s)**: Tesla drivers

# %%
aiid_data.sort_values(by = 'date', ascending = False).head(2)
# Out:
#                id                                              title  \
# 604  Incident 616  Sports Illustrated Is Alleged to Have Used AI ...
# 601  Incident 613  AI-Generated Images Available through Adobe St...
#
#                                            description       date  \
# 604  Sports Illustrated, managed by The Arena Group... 2023-11-27
# 601  AI-generated images available through Adobe St... 2023-11-23
#
#            alleged_deployer_of_ai_system alleged_developer_of_ai_system  \
# 604  The Arena Group, Sports Illustrated                        unknown
# 601                          Adobe Stock    Various AI image generators
#
#                alleged_harmed_or_nearly_harmed_parties  day  month  year
# 604  General public, Readers of Sports Illustrated,...   27     11  2023
# 601  General public, Journalistic integrity, News s...   23     11  2023

# %%
aiid_data['alleged_harmed_or_nearly_harmed_parties'] = aiid_data['alleged_harmed_or_nearly_harmed_parties'].str.replace(', ', ',').str.strip()

# %%
# Extract numeric part and convert to integers
aiid_data['id_num'] = aiid_data['id'].str.extract(r'(\d+)').astype(int)

# Move 'id_num' to the first position
aiid_data = aiid_data[['id_num'] + [col for col in aiid_data.columns if col != 'id_num']]

# Sort by id_num
aiid_data.sort_values('id_num', inplace=True)

aiid_data
# Out:
#      id_num            id                                              title  \
# 0         1    Incident 1  Google’s YouTube Kids App Presents Inappropria...
# 1         2    Incident 2  Warehouse robot ruptures can of bear spray and...
# 2         3    Incident 3  Crashes with Maneuvering Characteristics Augme...
# 3         4    Incident 4               Uber AV Killed Pedestrian in Arizona
# 4         5    Incident 5         Collection of Robotic Surgery Malfunctions
# ..      ...           ...                                                ...
# 600     612  Incident 612  Microsoft AI Poll Allegedly Causes Reputationa...
# 601     613  Incident 613  AI-Generated Images Available through Adobe St...
# 602     614  Incident 614  Google Bard Allegedly Generates False Allegati...
# 603     615  Incident 615  Colorado Lawyer Filed a Motion Citing Hallucin...
# 604     616  Incident 616  Sports Illustrated Is Alleged to Have Used AI ...
#
#                                            description       date  \
# 0    YouTube’s content filtering and recommendation... 2015-05-19
# 1    Twenty-four Amazon workers in New Jersey were ... 2018-12-05
# 2    A Boeing 737 crashed into the sea, killing 189... 2018-10-27
# 3    An Uber autonomous vehicle (AV) in autonomous ... 2018-03-18
# 4    Study on database reports of robotic surgery m... 2015-07-13
# ..                                                 ...        ...
# 600  An AI-generated poll by Microsoft, displayed a... 2023-10-31
# 601  AI-generated images available through Adobe St... 2023-11-23
# 602  Australian academics reportedly used Google Ba... 2023-11-02
# 603  A Colorado Springs attorney, Zachariah Crabill... 2023-06-13
# 604  Sports Illustrated, managed by The Arena Group... 2023-11-27
#
#            alleged_deployer_of_ai_system alleged_developer_of_ai_system  \
# 0                                YouTube                        YouTube
# 1                                 Amazon                         Amazon
# 2                                 Boeing                         Boeing
# 3                                   Uber                           Uber
# 4                     Hospitals, Doctors             Intuitive Surgical
# ..                                   ...                            ...
# 600                            Microsoft                      Microsoft
# 601                          Adobe Stock    Various AI image generators
# 602                        James Guthrie                    Google Bard
# 603                    Zachariah Crabill                OpenAI, ChatGPT
# 604  The Arena Group, Sports Illustrated                        unknown
#
#                alleged_harmed_or_nearly_harmed_parties  day  month  year
# 0                                             Children   19      5  2015
# 1                                    Warehouse Workers    5     12  2018
# 2                    Airplane Passengers,Airplane Crew   27     10  2018
# 3                          Elaine Herzberg,pedestrians   18      3  2018
# 4                                             patients   13      7  2015
# ..                                                 ...  ...    ...   ...
# 600                 The Guardian,Family of Lilie James   31     10  2023
# 601  General public,Journalistic integrity,News sou...   23     11  2023
# 602  James Guthrie,James Guthrie's co-authors,Parli...    2     11  2023
# 603  Legal system,Zachariah Crabill's client,Zachar...   13      6  2023
# 604  General public,Readers of Sports Illustrated,J...   27     11  2023
#
# [605 rows x 11 columns]

# %%
aiid_data_unique_harmed = pd.DataFrame(columns=aiid_data.columns)

for _, row in aiid_data.iterrows():
    harmed_parties = row['alleged_harmed_or_nearly_harmed_parties'].split(',')
    
    for party in harmed_parties:
        new_row = row.copy()
        new_row['alleged_harmed_or_nearly_harmed_parties'] = party.strip().lower()
        aiid_data_unique_harmed = pd.concat([aiid_data_unique_harmed, pd.DataFrame([new_row])], ignore_index=True)

# Sort the DataFrame by 'id_num' and reset the index
aiid_data_unique_harmed.sort_values('id_num', inplace=True)
aiid_data_unique_harmed.reset_index(drop=True, inplace=True)

aiid_data_unique_harmed
# Out:
#      id_num            id                                              title  \
# 0         1    Incident 1  Google’s YouTube Kids App Presents Inappropria...
# 1         2    Incident 2  Warehouse robot ruptures can of bear spray and...
# 2         3    Incident 3  Crashes with Maneuvering Characteristics Augme...
# 3         3    Incident 3  Crashes with Maneuvering Characteristics Augme...
# 4         4    Incident 4               Uber AV Killed Pedestrian in Arizona
# ...     ...           ...                                                ...
# 1178    615  Incident 615  Colorado Lawyer Filed a Motion Citing Hallucin...
# 1179    615  Incident 615  Colorado Lawyer Filed a Motion Citing Hallucin...
# 1180    616  Incident 616  Sports Illustrated Is Alleged to Have Used AI ...
# 1181    616  Incident 616  Sports Illustrated Is Alleged to Have Used AI ...
# 1182    616  Incident 616  Sports Illustrated Is Alleged to Have Used AI ...
#
#                                             description       date  \
# 0     YouTube’s content filtering and recommendation... 2015-05-19
# 1     Twenty-four Amazon workers in New Jersey were ... 2018-12-05
# 2     A Boeing 737 crashed into the sea, killing 189... 2018-10-27
# 3     A Boeing 737 crashed into the sea, killing 189... 2018-10-27
# 4     An Uber autonomous vehicle (AV) in autonomous ... 2018-03-18
# ...                                                 ...        ...
# 1178  A Colorado Springs attorney, Zachariah Crabill... 2023-06-13
# 1179  A Colorado Springs attorney, Zachariah Crabill... 2023-06-13
# 1180  Sports Illustrated, managed by The Arena Group... 2023-11-27
# 1181  Sports Illustrated, managed by The Arena Group... 2023-11-27
# 1182  Sports Illustrated, managed by The Arena Group... 2023-11-27
#
#             alleged_deployer_of_ai_system alleged_developer_of_ai_system  \
# 0                                 YouTube                        YouTube
# 1                                  Amazon                         Amazon
# 2                                  Boeing                         Boeing
# 3                                  Boeing                         Boeing
# 4                                    Uber                           Uber
# ...                                   ...                            ...
# 1178                    Zachariah Crabill                OpenAI, ChatGPT
# 1179                    Zachariah Crabill                OpenAI, ChatGPT
# 1180  The Arena Group, Sports Illustrated                        unknown
# 1181  The Arena Group, Sports Illustrated                        unknown
# 1182  The Arena Group, Sports Illustrated                        unknown
#
#      alleged_harmed_or_nearly_harmed_parties day month  year
# 0                                   children  19     5  2015
# 1                          warehouse workers   5    12  2018
# 2                        airplane passengers  27    10  2018
# 3                              airplane crew  27    10  2018
# 4                            elaine herzberg  18     3  2018
# ...                                      ...  ..   ...   ...
# 1178                            legal system  13     6  2023
# 1179                       zachariah crabill  13     6  2023
# 1180           readers of sports illustrated  27    11  2023
# 1181                          general public  27    11  2023
# 1182                  journalistic integrity  27    11  2023
#
# [1183 rows x 11 columns]

# %%
### Split the values in the 'alleged_harmed_or_nearly_harmed_parties' column
# and stack them into a new DataFrame
aiid_data_unique_harmed_counts = aiid_data_unique_harmed['alleged_harmed_or_nearly_harmed_parties']

# Rename the resulting Series to 'alleged_harmed_or_nearly_harmed_party'
aiid_data_unique_harmed_counts.name = 'alleged_harmed_or_nearly_harmed_party'

# Count the occurrences of each party
harmed_party_occurrences = aiid_data_unique_harmed_counts.value_counts()

# Display the result
harmed_party_occurrences_df = pd.DataFrame(harmed_party_occurrences).reset_index()
harmed_party_occurrences_df.head(30)
# Out:
#    alleged_harmed_or_nearly_harmed_party  count
# 0                         facebook users     28
# 1                         general public     24
# 2                          tesla drivers     20
# 3                          twitter users     15
# 4                                  women     12
# 5                        minority groups     12
# 6                           tiktok users     10
# 7                          youtube users      8
# 8                              microsoft      8
# 9                            pedestrians      7
# 10                       instagram users      7
# 11                                openai      6
# 12                          black people      6
# 13                    social media users      6
# 14                         jewish people      5
# 15                journalistic integrity      4
# 16                          uber drivers      4
# 17                        internet users      4
# 18                               unknown      4
# 19                              children      4
# 20                             motorists      4
# 21                      amazon customers      4
# 22                              teachers      4
# 23                  traffic participants      4
# 24                                minors      3
# 25                              patients      3
# 26                         chatgpt users      3
# 27                              students      3
# 28            san francisco firefighters      3
# 29                gender minority groups      3

# %%
mapping_dict = {
    'general public': 'general_public',
    'user': 'platform_users_customers',
    'users': 'platform_users_customers',
    'customer': 'platform_users_customers',
    'children': 'minors',
    'child': 'minors',
    'minors': 'minors',
    'teenagers': 'minors',
    'black': 'minority_groups',
    'latinx': 'minority_groups',
    'jewish': 'minority_groups',
    'women': 'minority_groups',
    'female': 'minority_groups',
    'non-male': 'minority_groups',
    'gender minority groups': 'minority_groups',
    'transgender': 'minority_groups',
    'non-binary': 'minority_groups',
    'gay': 'minority_groups',
    'african': 'minority_groups',
    'haitian': 'minority_groups',
    'black patients': 'minority_groups',
    'communities of color': 'minority_groups',
    'black students': 'minority_groups',
    'neighborhoods of color': 'minority_groups',
    'minority': 'minority_groups',
    'minorities': 'minority_groups',
    'non-Caucasian': 'minority_groups',
    'non-white': 'minority_groups',
    'low-income communities': 'minority_groups',
    'bipoc': 'minority_groups',
    'indigenous': 'minority_groups',
    'brown communities': 'minority_groups',
    'disab': 'minority_groups',
    'traffic participants': 'traffic_participants',
    'drivers': 'traffic_participants',
    'pedestrians': 'traffic_participants',
    'motorists': 'traffic_participants',
    'openai': 'developer_of_ai_system',
    'microsoft': 'developer_of_ai_system'
}

def map_categories(text):
    for term, category in mapping_dict.items():
        if term in text:
            return category
    return text

aiid_data_unique_harmed['alleged_harmed_or_nearly_harmed_generalized'] = aiid_data_unique_harmed['alleged_harmed_or_nearly_harmed_parties'].apply(map_categories)
aiid_data_unique_harmed[['alleged_harmed_or_nearly_harmed_parties','alleged_harmed_or_nearly_harmed_generalized']].head(5)
# Out:
#   alleged_harmed_or_nearly_harmed_parties  \
# 0                                children
# 1                       warehouse workers
# 2                     airplane passengers
# 3                           airplane crew
# 4                         elaine herzberg
#
#   alleged_harmed_or_nearly_harmed_generalized
# 0                                      minors
# 1                           warehouse workers
# 2                         airplane passengers
# 3                               airplane crew
# 4                             elaine herzberg

# %%
# Count occurrences of each unique value in the 'alleged_developer_of_ai_system' column
harmed_counts = aiid_data_unique_harmed['alleged_harmed_or_nearly_harmed_generalized'].value_counts()

# Drop the entry where the alleged developer is "unknown"
harmed_counts = harmed_counts.drop('unknown', errors='ignore')

# Select the top 10 values (including ties)
top_harmed = harmed_counts.head(6)

# Create a horizontal bar chart with the largest value at the top
plt.barh(top_harmed.index[::-1], top_harmed[::-1])

for index, value in zip(top_harmed.index[::-1], top_harmed[::-1]):
    plt.text(value, index, str(value), va='center')

# Add labels and title
plt.xlabel('Incident Count (Reported)')
plt.ylabel('Harmed/Nearly Harmed Parties')
plt.title('6 Groups Harmed or Nearly Harmed by 81% of Incidents')

# Display the plot
plt.show()

# Get and print the total counts for the top 6
total_counts_harmed = top_harmed.sum()
#print(f'Total counts for top 10: {total_counts_harmed}')
#print(f'% total incidents of top en: {total_counts_harmed / len(aiid_data)}')

# %%
bar_color = '#003262'
outline_color = '#FDB515'

# Count occurrences of each unique value in the 'alleged_developer_of_ai_system' column
harmed_counts = aiid_data_unique_harmed['alleged_harmed_or_nearly_harmed_generalized'].value_counts()

# Drop the entry where the alleged developer is "unknown"
harmed_counts = harmed_counts.drop('unknown', errors='ignore')

# Select the top 6 values (including ties)
top_harmed = harmed_counts.head(6)

# Create a horizontal bar chart with the largest value at the top
plt.barh(top_harmed.index[::-1],
         top_harmed[::-1],
         color=bar_color,      # Set the hex color for bars
         edgecolor=outline_color)  # Set the hex color for bar outlines

for index, value in zip(top_harmed.index[::-1], top_harmed[::-1]):
    plt.text(value, index, str(value), va='center')

# Add labels and title
plt.xlabel('Incident Count (Reported)')
plt.ylabel('Harmed/Nearly Harmed Parties')
plt.title('6 Groups Harmed or Nearly Harmed by 81% of Incidents')

# Display the plot
plt.show()

# %%
partial_string = 'location'
aiid_search = aiid_data[aiid_data['description'].str.contains(partial_string, case=False)]
pd.set_option('display.max_colwidth', None)
aiid_search.head(4)
# Out:
#      id_num            id  \
# 72       73   Incident 73
# 224     227  Incident 227
# 386     395  Incident 395
# 513     524  Incident 524
#
#                                                                             title  \
# 72        Is Pokémon Go racist? How the app may be redlining communities of color
# 224  Waze App Allegedly Caused Tourists’ Car to End up in Lake Champlain, Vermont
# 386            Amazon Forced Deployment of AI-Powered Cameras on Delivery Drivers
# 513          AI Voices Abused by Telegram User to Make Swat Calls as Paid Service
#
#                                                                                                                                                                                                                                             description  \
# 72                    Through a crowdsourcing social media campaign in 2016, several journalists and researchers demonstrated that augmented reality locations in the popular smartphone game Pokemon Go were more likely to be in white neighborhoods.
# 224              The tourists driving through Vermont blamed Waze for directing them into a boat launch in Lake Champlain, prompting the vehicle to slide into the water by the time the drivers realized their location in the dark and foggy weather.
# 386                                                                Amazon delivery drivers were forced to consent to algorithmic collection and processing of their location, movement, and biometric data through AI-powered cameras, or be dismissed.
# 513  Telegram channel Torswats offered paid service for and posted own recordings of false threats calls featuring AI-generated voices to direct armed law enforcement to raid locations of victims such as high schools, private residents, streamers.
#
#           date alleged_deployer_of_ai_system alleged_developer_of_ai_system  \
# 72  2016-03-01                  Niantic Labs                   Niantic Labs
# 224 2018-01-12                          Waze                           Waze
# 386 2021-03-02                        Amazon                      Netradyne
# 513 2023-02-12                      Torswats                        unknown
#
#                                                                                                                             alleged_harmed_or_nearly_harmed_parties  \
# 72                                                                                                                     non-white neighborhoods,communities of color
# 224                                                                                                                                             tourists,Waze users
# 386                                                                                                                                         Amazon delivery drivers
# 513  Your CBD Store,University of Pittsburgh Police Department,Phillipsburg High School,Hempstead High School,Dubuque Police Department,Bellefonte Area High School
#
#      day  month  year
# 72     1      3  2016
# 224   12      1  2018
# 386    2      3  2021
# 513   12      2  2023

# %%
# alleged_developer_of_ai_system has columns with multiple companies, I want to split them out to get the total count for each
aiid_data_unique_dev = pd.DataFrame(columns=aiid_data.columns)

for _, row in aiid_data.iterrows():
    alleged_dev = row['alleged_developer_of_ai_system'].split(',')
    
    for dev in alleged_dev:
        new_row = row.copy()
        new_row['alleged_developer_of_ai_system'] = dev.strip().lower()
        aiid_data_unique_dev = pd.concat([aiid_data_unique_dev, pd.DataFrame([new_row])], ignore_index=True)

# Sort the DataFrame by 'id_num' and reset the index
aiid_data_unique_dev.sort_values('id_num', inplace=True)
aiid_data_unique_dev.reset_index(drop=True, inplace=True)

aiid_data_unique_dev
# Out:
#     id_num            id  \
# 0        1    Incident 1
# 1        2    Incident 2
# 2        3    Incident 3
# 3        4    Incident 4
# 4        5    Incident 5
# ..     ...           ...
# 756    613  Incident 613
# 757    614  Incident 614
# 758    615  Incident 615
# 759    615  Incident 615
# 760    616  Incident 616
#
#                                                                                                                                          title  \
# 0                                                                                     Google’s YouTube Kids App Presents Inappropriate Content
# 1                                                                               Warehouse robot ruptures can of bear spray and injures workers
# 2                                                                          Crashes with Maneuvering Characteristics Augmentation System (MCAS)
# 3                                                                                                         Uber AV Killed Pedestrian in Arizona
# 4                                                                                                   Collection of Robotic Surgery Malfunctions
# ..                                                                                                                                         ...
# 756                                                           AI-Generated Images Available through Adobe Stock Misrepresent Real-World Events
# 757  Google Bard Allegedly Generates False Allegations Against Consulting Firms Used in Research Presented in Australian Parliamentary Inquiry
# 758                                                                           Colorado Lawyer Filed a Motion Citing Hallucinated ChatGPT Cases
# 759                                                                           Colorado Lawyer Filed a Motion Citing Hallucinated ChatGPT Cases
# 760                                                    Sports Illustrated Is Alleged to Have Used AI to Invent Fake Authors and Their Articles
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                        description  \
# 0                                                                                                                                                                                                                                                                                                                                               YouTube’s content filtering and recommendation algorithms exposed children to disturbing and inappropriate videos.
# 1                                                                                                                                                                                                                                                                                                                                 Twenty-four Amazon workers in New Jersey were hospitalized after a robot punctured a can of bear repellent spray in a warehouse.
# 2                                                                                                                                                                                                                                                                                             A Boeing 737 crashed into the sea, killing 189 people, after faulty sensor data caused an automated manuevering system to repeatedly push the plane's nose downward.
# 3                                                                                                                                                                                                                                                                                                                                                             An Uber autonomous vehicle (AV) in autonomous mode struck and killed a pedestrian in Tempe, Arizona.
# 4                                                                                                                                                                                                                                                                                                              Study on database reports of robotic surgery malfunctions (8,061), including those ending in injury (1,391) and death (144), between 2000 and 2013.
# ..                                                                                                                                                                                                                                                                                                                                                                                                                                                             ...
# 756  AI-generated images available through Adobe Stock, depicting realistic but fictional scenes of real-world events like wars and protests, have raised significant ethical concerns. These images blurred the lines between reality and fiction in journalistic contexts, prompting Adobe Stock to "crack down on AI-generated images that seem to depict real, newsworthy events and take new steps to prevent its images from being used in misleading ways."
# 757                                                      Australian academics reportedly used Google Bard AI to generate case studies for a parliamentary inquiry, leading to false allegations against major consultancy firms. The AI-generated misinformation prompted an apology from the academics, causing reputational harm for all parties involved and raising concerns about the reliability of AI tools in producing accurate and unbiased information.
# 758                                                                                                                                                        A Colorado Springs attorney, Zachariah Crabill, mistakenly used hallucinated ChatGPT-generated legal cases in court documents. The AI software provided false case citations, leading to the denial of a motion and legal repercussions for Crabill, highlighting risks in using AI for legal research.
# 759                                                                                                                                                        A Colorado Springs attorney, Zachariah Crabill, mistakenly used hallucinated ChatGPT-generated legal cases in court documents. The AI software provided false case citations, leading to the denial of a motion and legal repercussions for Crabill, highlighting risks in using AI for legal research.
# 760                    Sports Illustrated, managed by The Arena Group, allegedly used AI-generated authors and content, compromising journalistic integrity. Profiles of these fictitious authors, complete with AI-generated headshots, appeared alongside articles, misleading readers. The issue was exposed when inconsistencies in author identities and writing quality were noticed, leading to the removal of this content from the publication's website.
#
#           date        alleged_deployer_of_ai_system  \
# 0   2015-05-19                              YouTube
# 1   2018-12-05                               Amazon
# 2   2018-10-27                               Boeing
# 3   2018-03-18                                 Uber
# 4   2015-07-13                   Hospitals, Doctors
# ..         ...                                  ...
# 756 2023-11-23                          Adobe Stock
# 757 2023-11-02                        James Guthrie
# 758 2023-06-13                    Zachariah Crabill
# 759 2023-06-13                    Zachariah Crabill
# 760 2023-11-27  The Arena Group, Sports Illustrated
#
#     alleged_developer_of_ai_system  \
# 0                          youtube
# 1                           amazon
# 2                           boeing
# 3                             uber
# 4               intuitive surgical
# ..                             ...
# 756    various ai image generators
# 757                    google bard
# 758                        chatgpt
# 759                         openai
# 760                        unknown
#
#                                             alleged_harmed_or_nearly_harmed_parties  \
# 0                                                                          Children
# 1                                                                 Warehouse Workers
# 2                                                 Airplane Passengers,Airplane Crew
# 3                                                       Elaine Herzberg,pedestrians
# 4                                                                          patients
# ..                                                                              ...
# 756                              General public,Journalistic integrity,News sources
# 757  James Guthrie,James Guthrie's co-authors,Parliament of Australia,KPMG,Deloitte
# 758                       Legal system,Zachariah Crabill's client,Zachariah Crabill
# 759                       Legal system,Zachariah Crabill's client,Zachariah Crabill
# 760             General public,Readers of Sports Illustrated,Journalistic integrity
#
#     day month  year
# 0    19     5  2015
# 1     5    12  2018
# 2    27    10  2018
# 3    18     3  2018
# 4    13     7  2015
# ..   ..   ...   ...
# 756  23    11  2023
# 757   2    11  2023
# 758  13     6  2023
# 759  13     6  2023
# 760  27    11  2023
#
# [761 rows x 11 columns]

# %%
aiid_data_unique_dev['alleged_developer_of_ai_system'].value_counts().head(25)
# Out:
# alleged_developer_of_ai_system
# unknown         88
# openai          49
# facebook        47
# tesla           42
# google          37
# amazon          24
# microsoft       17
# youtube         13
# cruise          12
# apple           11
# meta            10
# tiktok          10
# uber            10
# twitter          9
# instagram        9
# stability ai     7
# shotspotter      6
# clearview ai     6
# laion            6
# replika          5
# runway           5
# eleutherai       5
# compvis lmu      5
# knightscope      4
# elevenlabs       4
# Name: count, dtype: int64

# %%
# Count occurrences of each unique value in the 'alleged_developer_of_ai_system' column
developer_counts = aiid_data_unique_dev['alleged_developer_of_ai_system'].value_counts()

# Drop the entry where the alleged developer is "unknown"
developer_counts = developer_counts.drop('unknown', errors='ignore')

# Select the top 10 values (including ties)
top_developers = developer_counts.head(10)

# Create a horizontal bar chart with the largest value at the top
plt.barh(top_developers.index[::-1], top_developers[::-1])

for index, value in zip(top_developers.index[::-1], top_developers[::-1]):
    plt.text(value, index, str(value), va='center')

# Add labels and title
plt.xlabel('Incident Count (Reported)')
plt.ylabel('Alleged Developer of AI System')
plt.title('10 Organizations Account for 43% of All Reported AIID Incidents')

# Display the plot
plt.show()

# Get and print the total counts for the top 10
total_counts = top_developers.sum()
#print(f'Total counts for top 10: {total_counts}')
#print(f'% total incidents of top en: {total_counts / len(aiid_data)}')

# %%
bar_color = '#003262'
outline_color = '#FDB515'

# Count occurrences of each unique value in the 'alleged_developer_of_ai_system' column
developer_counts = aiid_data_unique_dev['alleged_developer_of_ai_system'].value_counts()

# Drop the entry where the alleged developer is "unknown"
developer_counts = developer_counts.drop('unknown', errors='ignore')

# Select the top 10 values (including ties)
top_developers = developer_counts.head(10)

# Create a horizontal bar chart with the largest value at the top
plt.barh(top_developers.index[::-1],
         top_developers[::-1],
         color=bar_color)  # Set the hex color for bar outlines

for index, value in zip(top_developers.index[::-1], top_developers[::-1]):
    plt.text(value, index, str(value), va='center')

# Add labels and title
plt.xlabel('Incident Count (Reported)')
plt.ylabel('Alleged Developer of AI System')
plt.title('10 Organizations Account for 43% of All Reported AIID Incidents')

# Display the plot
plt.show()

# %%
# alleged_deployer_of_ai_system has columns with multiple companies, I want to split them out to get the total count for each
aiid_data_unique_dep = pd.DataFrame(columns=aiid_data.columns)

for _, row in aiid_data.iterrows():
    alleged_dep = row['alleged_deployer_of_ai_system'].split(',')
    
    for dep in alleged_dep:
        new_row = row.copy()
        new_row['alleged_deployer_of_ai_system'] = dep.strip().lower()
        aiid_data_unique_dep = pd.concat([aiid_data_unique_dep, pd.DataFrame([new_row])], ignore_index=True)

# Sort the DataFrame by 'id_num' and reset the index
aiid_data_unique_dep.sort_values('id_num', inplace=True)
aiid_data_unique_dep.reset_index(drop=True, inplace=True)

print(len(aiid_data_unique_dep))
aiid_data_unique_dep.head(2)
# Out:
# 762
#   id_num          id  \
# 0      1  Incident 1
# 1      2  Incident 2
#
#                                                             title  \
# 0        Google’s YouTube Kids App Presents Inappropriate Content
# 1  Warehouse robot ruptures can of bear spray and injures workers
#
#                                                                                                                         description  \
# 0                YouTube’s content filtering and recommendation algorithms exposed children to disturbing and inappropriate videos.
# 1  Twenty-four Amazon workers in New Jersey were hospitalized after a robot punctured a can of bear repellent spray in a warehouse.
#
#         date alleged_deployer_of_ai_system alleged_developer_of_ai_system  \
# 0 2015-05-19                       youtube                        YouTube
# 1 2018-12-05                        amazon                         Amazon
#
#   alleged_harmed_or_nearly_harmed_parties day month  year
# 0                                Children  19     5  2015
# 1                       Warehouse Workers   5    12  2018

# %%
# Count occurrences of each unique value in the 'alleged_deployer_of_ai_system' column
deployer_counts = aiid_data_unique_dep['alleged_deployer_of_ai_system'].value_counts()

# Drop the entry where the alleged deployer is "unknown"
deployer_counts = deployer_counts.drop('unknown', errors='ignore')

# Select the top 10 values (including ties)
top_deployers = deployer_counts.head(10)

# Create a horizontal bar chart with the largest value at the top
plt.barh(top_deployers.index[::-1], top_deployers[::-1])

for index, value in zip(top_deployers.index[::-1], top_deployers[::-1]):
    plt.text(value, index, str(value), va='center')

# Add labels and title
plt.xlabel('Count')
plt.ylabel('Alleged Deployer of AI System')
plt.title('Top 10 Deployers of AI System in AIID (Excluding "unknown")')

# Display the plot
plt.show()

# Get and print the total counts for the top 10
total_counts = top_deployers.sum()
print(f'Total counts for top 10: {total_counts}')
print(f'% total incidents of top en: {total_counts / len(aiid_data)}')
# Out:
# Total counts for top 10: 228
# % total incidents of top en: 0.3768595041322314
